# %% [markdown]
# # Imports

# %%
import fiftyone as fo
import fiftyone.utils.coco as fouc
from fiftyone.core.labels import Detection
from PIL import Image

import torch
import torch.nn as nn
import torch.utils
import torch.utils.data

import torchvision
from torchvision.models.segmentation import fcn_resnet50, FCN_ResNet50_Weights
from torchvision.models.detection import fasterrcnn_resnet50_fpn, FasterRCNN_ResNet50_FPN_Weights
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import matplotlib.pyplot as plt

import os
import sys
import importlib
import time
from pathlib import Path
from datetime import datetime

import utils
import train
from engine import train_one_epoch, evaluate
#from train import train_one_epoch, evaluate
import transforms
sys.path.insert(0, '..')
import DatasetLoaders as DatasetLoaders
importlib.reload(DatasetLoaders)
from DatasetLoaders import HRSIDDetectionDataset
importlib.reload(utils)
importlib.reload(transforms)
importlib.reload(train)
# Out:
# <module 'train' from '/home/k3vinli/ENEE439/Capstone/models/faster_rcnn_resnet/train.py'>

# %% [markdown]
# # Loading Data

# %%
p = Path()
top_dir = p.absolute().parents[1]
top_dir
# Out:
# PosixPath('/home/k3vinli/ENEE439/Capstone')

# %%
# Loading Dataset
name = "HRSID"
if name in fo.list_datasets():
    dataset_traintest = fo.load_dataset(name)
else:
    dataset_dir = top_dir / "Datasets" / "HRSID"
    # The type of the dataset being imported
    dataset_type = fo.types.COCODetectionDataset

    dataset_traintest = fo.Dataset.from_dir(
        dataset_dir=dataset_dir,
        dataset_type=dataset_type,
        name=name,
    )

# %%
# dataset_traintest.delete()

# %%
name = "HRSID_train"
if name in fo.list_datasets():
    dataset_train = fo.load_dataset(name)
else:
    dataset_dir = top_dir / "Datasets" / "HRSID"
    label_path = top_dir / "Datasets"/ "HRSID" / "annotations" / "train2017.json"
    # The type of the dataset being imported
    dataset_type = fo.types.COCODetectionDataset

    dataset_train = fo.Dataset.from_dir(
        dataset_dir=dataset_dir,
        dataset_type=dataset_type,
        name=name,
        labels_path=label_path
    )

# %%
name = "HRSID_test"
if name in fo.list_datasets():
    dataset_test = fo.load_dataset(name)
else:
    dataset_dir = top_dir / "Datasets" / "HRSID"
    label_path = top_dir / "Datasets"/ "HRSID" / "annotations" / "test2017.json"
    # The type of the dataset being imported
    dataset_type = fo.types.COCODetectionDataset

    dataset_test = fo.Dataset.from_dir(
        dataset_dir=dataset_dir,
        dataset_type=dataset_type,
        name=name,
        labels_path=label_path
    )

# %%
# dataset_traintest.delete()

# %%
dataset_train.compute_metadata()
dataset_test.compute_metadata()

# %%
session = fo.launch_app()
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=7865f141-7505-435e-925e-4a0c25035dca"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def get_model(num_classes):
    weights = FasterRCNN_ResNet50_FPN_Weights.DEFAULT
    transforms = weights.transforms()
    model = fasterrcnn_resnet50_fpn(weights=weights)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model

# %%
def do_training(model, torch_dataset, torch_dataset_test, num_epochs=4):
    # define training and validation data loaders
    data_loader = torch.utils.data.DataLoader(
        torch_dataset, batch_size=10, shuffle=True, num_workers=2,
        collate_fn=utils.collate_fn)
    
    data_loader_test = torch.utils.data.DataLoader(
        torch_dataset_test, batch_size=10, shuffle=False, num_workers=2,
        collate_fn=utils.collate_fn)

    # train on the GPU or on the CPU, if a GPU is not available
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    print("Using device %s" % device)

    # move model to the right device
    model.to(device)

    # construct an optimizer
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.SGD(params, lr=0.005,
                                momentum=0.9, weight_decay=0.0005)
    # and a learning rate scheduler
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                    step_size=3,
                                                    gamma=0.1)

    for epoch in range(num_epochs):
        # train for one epoch, printing every 10 iterations
        train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)

        # update the learning rate
        lr_scheduler.step()
        # evaluate on the test dataset
        evaluate(model, data_loader_test, device=device)

# %%
train_transforms = transforms.Compose([transforms.PILToTensor(), transforms.ConvertImageDtype(torch.float)])
test_transforms = transforms.Compose([transforms.PILToTensor(), transforms.ConvertImageDtype(torch.float)])

# %%
torch_dataset = HRSIDDetectionDataset(dataset_train, train_transforms)
torch_dataset_test = HRSIDDetectionDataset(dataset_test, test_transforms)

# %%
model = get_model(2)

# %%
do_training(model, torch_dataset, torch_dataset_test, num_epochs=15)
# Out:
# Using device cuda
# Epoch: [0]  [  0/365]  eta: 0:32:40  lr: 0.000019  loss: 1.0524 (1.0524)  loss_classifier: 0.5767 (0.5767)  loss_box_reg: 0.1412 (0.1412)  loss_objectness: 0.2819 (0.2819)  loss_rpn_box_reg: 0.0526 (0.0526)  time: 5.3706  data: 0.5320  max mem: 6243
# Epoch: [0]  [ 10/365]  eta: 0:15:47  lr: 0.000156  loss: 1.0524 (1.1729)  loss_classifier: 0.4788 (0.4476)  loss_box_reg: 0.1210 (0.1333)  loss_objectness: 0.2819 (0.5434)  loss_rpn_box_reg: 0.0514 (0.0486)  time: 2.6703  data: 0.0728  max mem: 6402
# Epoch: [0]  [ 20/365]  eta: 0:12:58  lr: 0.000293  loss: 0.6852 (0.9050)  loss_classifier: 0.2497 (0.3290)  loss_box_reg: 0.1688 (0.1677)  loss_objectness: 0.1673 (0.3573)  loss_rpn_box_reg: 0.0387 (0.0512)  time: 2.1021  data: 0.0277  max mem: 6402
# Epoch: [0]  [ 30/365]  eta: 0:11:43  lr: 0.000430  loss: 0.5103 (0.7692)  loss_classifier: 0.1663 (0.2748)  loss_box_reg: 0.1982 (0.1766)  loss_objectness: 0.0726 (0.2689)  loss_rpn_box_reg: 0.0370 (0.0489)  time: 1.7848  data: 0.0286  max mem: 6402
# Epoch: [0]  [ 40/365]  eta: 0:11:53  lr: 0.000568  loss: 0.4242 (0.6900)  loss_classifier: 0.1567 (0.2428)  loss_box_reg: 0.1982 (0.1890)  loss_objectness: 0.0307 (0.2145)  loss_rpn_box_reg: 0.0257 (0.0437)  time: 2.1303  data: 0.0287  max mem: 6402
# Epoch: [0]  [ 50/365]  eta: 0:11:51  lr: 0.000705  loss: 0.4211 (0.6356)  loss_classifier: 0.1151 (0.2168)  loss_box_reg: 0.2296 (0.1949)  loss_objectness: 0.0341 (0.1819)  loss_rpn_box_reg: 0.0178 (0.0420)  time: 2.5025  data: 0.0287  max mem: 6402
# Epoch: [0]  [ 60/365]  eta: 0:11:41  lr: 0.000842  loss: 0.3873 (0.5926)  loss_classifier: 0.1026 (0.1978)  loss_box_reg: 0.2078 (0.1991)  loss_objectness: 0.0276 (0.1564)  loss_rpn_box_reg: 0.0217 (0.0393)  time: 2.5164  data: 0.0286  max mem: 6402
# Epoch: [0]  [ 70/365]  eta: 0:11:26  lr: 0.000979  loss: 0.3812 (0.5612)  loss_classifier: 0.0966 (0.1832)  loss_box_reg: 0.1961 (0.2006)  loss_objectness: 0.0276 (0.1395)  loss_rpn_box_reg: 0.0217 (0.0379)  time: 2.5108  data: 0.0286  max mem: 6402
# Epoch: [0]  [ 80/365]  eta: 0:11:11  lr: 0.001117  loss: 0.3450 (0.5318)  loss_classifier: 0.0759 (0.1694)  loss_box_reg: 0.1828 (0.1962)  loss_objectness: 0.0359 (0.1285)  loss_rpn_box_reg: 0.0243 (0.0377)  time: 2.5185  data: 0.0286  max mem: 6402
# Epoch: [0]  [ 90/365]  eta: 0:10:51  lr: 0.001254  loss: 0.3244 (0.5061)  loss_classifier: 0.0747 (0.1586)  loss_box_reg: 0.1746 (0.1940)  loss_objectness: 0.0262 (0.1172)  loss_rpn_box_reg: 0.0240 (0.0363)  time: 2.5151  data: 0.0286  max mem: 6402
# Epoch: [0]  [100/365]  eta: 0:10:44  lr: 0.001391  loss: 0.2588 (0.4842)  loss_classifier: 0.0619 (0.1491)  loss_box_reg: 0.1528 (0.1897)  loss_objectness: 0.0201 (0.1097)  loss_rpn_box_reg: 0.0193 (0.0356)  time: 2.7474  data: 0.0288  max mem: 6402
# Epoch: [0]  [110/365]  eta: 0:10:23  lr: 0.001528  loss: 0.2142 (0.4605)  loss_classifier: 0.0510 (0.1405)  loss_box_reg: 0.1384 (0.1837)  loss_objectness: 0.0152 (0.1015)  loss_rpn_box_reg: 0.0157 (0.0348)  time: 2.7846  data: 0.0288  max mem: 6402
# Epoch: [0]  [120/365]  eta: 0:10:01  lr: 0.001665  loss: 0.2034 (0.4412)  loss_classifier: 0.0510 (0.1334)  loss_box_reg: 0.1286 (0.1794)  loss_objectness: 0.0132 (0.0946)  loss_rpn_box_reg: 0.0171 (0.0338)  time: 2.5580  data: 0.0285  max mem: 6402
# Epoch: [0]  [130/365]  eta: 0:09:38  lr: 0.001803  loss: 0.1836 (0.4218)  loss_classifier: 0.0470 (0.1269)  loss_box_reg: 0.1096 (0.1732)  loss_objectness: 0.0132 (0.0890)  loss_rpn_box_reg: 0.0152 (0.0327)  time: 2.5551  data: 0.0288  max mem: 6402
# Epoch: [0]  [140/365]  eta: 0:09:15  lr: 0.001940  loss: 0.1836 (0.4096)  loss_classifier: 0.0434 (0.1225)  loss_box_reg: 0.0847 (0.1690)  loss_objectness: 0.0168 (0.0849)  loss_rpn_box_reg: 0.0177 (0.0331)  time: 2.5509  data: 0.0289  max mem: 6402
# Epoch: [0]  [150/365]  eta: 0:08:53  lr: 0.002077  loss: 0.1958 (0.3950)  loss_classifier: 0.0498 (0.1179)  loss_box_reg: 0.0946 (0.1641)  loss_objectness: 0.0168 (0.0806)  loss_rpn_box_reg: 0.0263 (0.0325)  time: 2.6240  data: 0.0284  max mem: 6402
# Epoch: [0]  [160/365]  eta: 0:08:32  lr: 0.002214  loss: 0.1884 (0.3845)  loss_classifier: 0.0498 (0.1143)  loss_box_reg: 0.0954 (0.1606)  loss_objectness: 0.0171 (0.0773)  loss_rpn_box_reg: 0.0243 (0.0323)  time: 2.7326  data: 0.0284  max mem: 6402
# Epoch: [0]  [170/365]  eta: 0:08:08  lr: 0.002352  loss: 0.1928 (0.3722)  loss_classifier: 0.0572 (0.1106)  loss_box_reg: 0.1027 (0.1564)  loss_objectness: 0.0196 (0.0739)  loss_rpn_box_reg: 0.0120 (0.0313)  time: 2.6600  data: 0.0285  max mem: 6402
# Epoch: [0]  [180/365]  eta: 0:07:42  lr: 0.002489  loss: 0.1571 (0.3608)  loss_classifier: 0.0351 (0.1067)  loss_box_reg: 0.0788 (0.1525)  loss_objectness: 0.0103 (0.0707)  loss_rpn_box_reg: 0.0118 (0.0308)  time: 2.5088  data: 0.0285  max mem: 6402
# Epoch: [0]  [190/365]  eta: 0:07:17  lr: 0.002626  loss: 0.1455 (0.3503)  loss_classifier: 0.0328 (0.1034)  loss_box_reg: 0.0787 (0.1491)  loss_objectness: 0.0103 (0.0677)  loss_rpn_box_reg: 0.0151 (0.0301)  time: 2.4963  data: 0.0285  max mem: 6402
# Epoch: [0]  [200/365]  eta: 0:06:54  lr: 0.002763  loss: 0.1455 (0.3414)  loss_classifier: 0.0415 (0.1006)  loss_box_reg: 0.0823 (0.1462)  loss_objectness: 0.0115 (0.0651)  loss_rpn_box_reg: 0.0151 (0.0295)  time: 2.5846  data: 0.0284  max mem: 6402
# Epoch: [0]  [210/365]  eta: 0:06:29  lr: 0.002900  loss: 0.1508 (0.3329)  loss_classifier: 0.0467 (0.0980)  loss_box_reg: 0.0750 (0.1433)  loss_objectness: 0.0067 (0.0628)  loss_rpn_box_reg: 0.0117 (0.0288)  time: 2.5754  data: 0.0286  max mem: 6402
# Epoch: [0]  [220/365]  eta: 0:06:03  lr: 0.003038  loss: 0.1820 (0.3276)  loss_classifier: 0.0535 (0.0964)  loss_box_reg: 0.0798 (0.1421)  loss_objectness: 0.0120 (0.0608)  loss_rpn_box_reg: 0.0117 (0.0283)  time: 2.5176  data: 0.0287  max mem: 6402
# Epoch: [0]  [230/365]  eta: 0:05:38  lr: 0.003175  loss: 0.2154 (0.3219)  loss_classifier: 0.0544 (0.0946)  loss_box_reg: 0.1105 (0.1404)  loss_objectness: 0.0131 (0.0589)  loss_rpn_box_reg: 0.0199 (0.0280)  time: 2.4963  data: 0.0286  max mem: 6402
# Epoch: [0]  [240/365]  eta: 0:05:13  lr: 0.003312  loss: 0.2152 (0.3172)  loss_classifier: 0.0496 (0.0930)  loss_box_reg: 0.1000 (0.1390)  loss_objectness: 0.0131 (0.0572)  loss_rpn_box_reg: 0.0199 (0.0279)  time: 2.4437  data: 0.0285  max mem: 6402
# Epoch: [0]  [250/365]  eta: 0:04:49  lr: 0.003449  loss: 0.1608 (0.3115)  loss_classifier: 0.0494 (0.0913)  loss_box_reg: 0.0910 (0.1371)  loss_objectness: 0.0106 (0.0557)  loss_rpn_box_reg: 0.0142 (0.0275)  time: 2.5951  data: 0.0288  max mem: 6402
# Epoch: [0]  [260/365]  eta: 0:04:24  lr: 0.003587  loss: 0.1525 (0.3060)  loss_classifier: 0.0489 (0.0896)  loss_box_reg: 0.0780 (0.1351)  loss_objectness: 0.0140 (0.0543)  loss_rpn_box_reg: 0.0104 (0.0270)  time: 2.6340  data: 0.0291  max mem: 6402
# Epoch: [0]  [270/365]  eta: 0:03:59  lr: 0.003724  loss: 0.1313 (0.3011)  loss_classifier: 0.0374 (0.0880)  loss_box_reg: 0.0708 (0.1334)  loss_objectness: 0.0155 (0.0530)  loss_rpn_box_reg: 0.0077 (0.0267)  time: 2.5849  data: 0.0289  max mem: 6402
# Epoch: [0]  [280/365]  eta: 0:03:34  lr: 0.003861  loss: 0.1287 (0.2951)  loss_classifier: 0.0369 (0.0862)  loss_box_reg: 0.0700 (0.1312)  loss_objectness: 0.0116 (0.0515)  loss_rpn_box_reg: 0.0098 (0.0262)  time: 2.6535  data: 0.0294  max mem: 6402
# Epoch: [0]  [290/365]  eta: 0:03:07  lr: 0.003998  loss: 0.1339 (0.2907)  loss_classifier: 0.0369 (0.0847)  loss_box_reg: 0.0694 (0.1297)  loss_objectness: 0.0089 (0.0504)  loss_rpn_box_reg: 0.0098 (0.0259)  time: 2.2848  data: 0.0302  max mem: 6402
# Epoch: [0]  [300/365]  eta: 0:02:42  lr: 0.004135  loss: 0.1472 (0.2866)  loss_classifier: 0.0395 (0.0833)  loss_box_reg: 0.0825 (0.1283)  loss_objectness: 0.0092 (0.0492)  loss_rpn_box_reg: 0.0119 (0.0258)  time: 2.0856  data: 0.0295  max mem: 6402
# Epoch: [0]  [310/365]  eta: 0:02:17  lr: 0.004273  loss: 0.1559 (0.2828)  loss_classifier: 0.0414 (0.0821)  loss_box_reg: 0.0822 (0.1272)  loss_objectness: 0.0075 (0.0480)  loss_rpn_box_reg: 0.0153 (0.0255)  time: 2.3620  data: 0.0287  max mem: 6402
# Epoch: [0]  [320/365]  eta: 0:01:51  lr: 0.004410  loss: 0.1398 (0.2792)  loss_classifier: 0.0414 (0.0807)  loss_box_reg: 0.0771 (0.1257)  loss_objectness: 0.0075 (0.0474)  loss_rpn_box_reg: 0.0107 (0.0254)  time: 2.3777  data: 0.0288  max mem: 6402
# Epoch: [0]  [330/365]  eta: 0:01:27  lr: 0.004547  loss: 0.1297 (0.2750)  loss_classifier: 0.0317 (0.0794)  loss_box_reg: 0.0739 (0.1242)  loss_objectness: 0.0117 (0.0463)  loss_rpn_box_reg: 0.0107 (0.0251)  time: 2.3768  data: 0.0287  max mem: 6402
# Epoch: [0]  [340/365]  eta: 0:01:02  lr: 0.004684  loss: 0.1592 (0.2736)  loss_classifier: 0.0469 (0.0790)  loss_box_reg: 0.0867 (0.1239)  loss_objectness: 0.0163 (0.0456)  loss_rpn_box_reg: 0.0142 (0.0251)  time: 2.5165  data: 0.0286  max mem: 6402
# Epoch: [0]  [350/365]  eta: 0:00:37  lr: 0.004822  loss: 0.1950 (0.2721)  loss_classifier: 0.0484 (0.0783)  loss_box_reg: 0.0939 (0.1234)  loss_objectness: 0.0190 (0.0452)  loss_rpn_box_reg: 0.0155 (0.0252)  time: 2.4985  data: 0.0286  max mem: 6402
# Epoch: [0]  [360/365]  eta: 0:00:12  lr: 0.004959  loss: 0.1566 (0.2690)  loss_classifier: 0.0462 (0.0774)  loss_box_reg: 0.0835 (0.1223)  loss_objectness: 0.0121 (0.0444)  loss_rpn_box_reg: 0.0135 (0.0249)  time: 1.9425  data: 0.0287  max mem: 6402
# Epoch: [0] Total time: 0:14:51
# creating index...
# index created!
# Test:  [  0/197]  eta: 0:03:17  model_time: 0.6235 (0.6235)  evaluator_time: 0.0111 (0.0111)  time: 1.0048  data: 0.3439  max mem: 6402
# Test:  [100/197]  eta: 0:00:57  model_time: 0.5176 (0.5384)  evaluator_time: 0.0060 (0.0077)  time: 0.5679  data: 0.0289  max mem: 6402
# Test: Total time: 0:01:56
# Averaged stats: model_time: 0.5246 (0.5331)  evaluator_time: 0.0162 (0.0158)
# Accumulating evaluation results...
# DONE (t=0.28s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.521
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.803
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.605
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.665
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.423
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.502
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.568
# Epoch: [1]  [  0/365]  eta: 0:26:29  lr: 0.005000  loss: 0.1747 (0.1747)  loss_classifier: 0.0551 (0.0551)  loss_box_reg: 0.1031 (0.1031)  loss_objectness: 0.0120 (0.0120)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 4.3558  data: 0.3976  max mem: 6402
# Epoch: [1]  [ 10/365]  eta: 0:10:31  lr: 0.005000  loss: 0.1912 (0.1993)  loss_classifier: 0.0514 (0.0531)  loss_box_reg: 0.1071 (0.1089)  loss_objectness: 0.0120 (0.0127)  loss_rpn_box_reg: 0.0209 (0.0246)  time: 1.7800  data: 0.0626  max mem: 6403
# Epoch: [1]  [ 20/365]  eta: 0:12:21  lr: 0.005000  loss: 0.1841 (0.1773)  loss_classifier: 0.0476 (0.0475)  loss_box_reg: 0.1027 (0.0968)  loss_objectness: 0.0090 (0.0117)  loss_rpn_box_reg: 0.0173 (0.0214)  time: 2.0395  data: 0.0288  max mem: 6404
# Epoch: [1]  [ 30/365]  eta: 0:10:13  lr: 0.005000  loss: 0.1473 (0.1715)  loss_classifier: 0.0395 (0.0468)  loss_box_reg: 0.0797 (0.0928)  loss_objectness: 0.0072 (0.0118)  loss_rpn_box_reg: 0.0121 (0.0201)  time: 1.8610  data: 0.0287  max mem: 6404
# Epoch: [1]  [ 40/365]  eta: 0:09:04  lr: 0.005000  loss: 0.1483 (0.1665)  loss_classifier: 0.0395 (0.0454)  loss_box_reg: 0.0797 (0.0906)  loss_objectness: 0.0063 (0.0109)  loss_rpn_box_reg: 0.0145 (0.0195)  time: 1.1794  data: 0.0289  max mem: 6404
# Epoch: [1]  [ 50/365]  eta: 0:08:16  lr: 0.005000  loss: 0.1765 (0.1730)  loss_classifier: 0.0500 (0.0464)  loss_box_reg: 0.0894 (0.0955)  loss_objectness: 0.0078 (0.0113)  loss_rpn_box_reg: 0.0158 (0.0198)  time: 1.1791  data: 0.0288  max mem: 6404
# Epoch: [1]  [ 60/365]  eta: 0:07:41  lr: 0.005000  loss: 0.1778 (0.1745)  loss_classifier: 0.0478 (0.0468)  loss_box_reg: 0.1047 (0.0964)  loss_objectness: 0.0078 (0.0116)  loss_rpn_box_reg: 0.0126 (0.0197)  time: 1.1750  data: 0.0289  max mem: 6404
# Epoch: [13]  [280/365]  eta: 0:01:54  lr: 0.000000  loss: 0.0950 (0.1169)  loss_classifier: 0.0287 (0.0325)  loss_box_reg: 0.0558 (0.0679)  loss_objectness: 0.0019 (0.0042)  loss_rpn_box_reg: 0.0059 (0.0123)  time: 1.2121  data: 0.0295  max mem: 6404
# Epoch: [13]  [290/365]  eta: 0:01:40  lr: 0.000000  loss: 0.1101 (0.1168)  loss_classifier: 0.0287 (0.0325)  loss_box_reg: 0.0650 (0.0677)  loss_objectness: 0.0025 (0.0042)  loss_rpn_box_reg: 0.0128 (0.0124)  time: 1.2098  data: 0.0294  max mem: 6404
# Epoch: [13]  [300/365]  eta: 0:01:27  lr: 0.000000  loss: 0.0829 (0.1158)  loss_classifier: 0.0258 (0.0323)  loss_box_reg: 0.0512 (0.0672)  loss_objectness: 0.0015 (0.0041)  loss_rpn_box_reg: 0.0047 (0.0121)  time: 1.2096  data: 0.0293  max mem: 6404
# Epoch: [13]  [310/365]  eta: 0:01:13  lr: 0.000000  loss: 0.0829 (0.1155)  loss_classifier: 0.0251 (0.0322)  loss_box_reg: 0.0505 (0.0670)  loss_objectness: 0.0018 (0.0041)  loss_rpn_box_reg: 0.0072 (0.0122)  time: 1.2092  data: 0.0293  max mem: 6404
# Epoch: [13]  [320/365]  eta: 0:00:59  lr: 0.000000  loss: 0.1015 (0.1157)  loss_classifier: 0.0272 (0.0322)  loss_box_reg: 0.0590 (0.0671)  loss_objectness: 0.0044 (0.0041)  loss_rpn_box_reg: 0.0112 (0.0123)  time: 1.2061  data: 0.0294  max mem: 6404
# Epoch: [13]  [330/365]  eta: 0:00:46  lr: 0.000000  loss: 0.1020 (0.1151)  loss_classifier: 0.0272 (0.0320)  loss_box_reg: 0.0613 (0.0668)  loss_objectness: 0.0023 (0.0041)  loss_rpn_box_reg: 0.0077 (0.0121)  time: 1.2087  data: 0.0297  max mem: 6404
# Epoch: [13]  [340/365]  eta: 0:00:33  lr: 0.000000  loss: 0.0869 (0.1146)  loss_classifier: 0.0255 (0.0320)  loss_box_reg: 0.0529 (0.0666)  loss_objectness: 0.0019 (0.0041)  loss_rpn_box_reg: 0.0049 (0.0120)  time: 1.2099  data: 0.0297  max mem: 6404
# Epoch: [13]  [350/365]  eta: 0:00:19  lr: 0.000000  loss: 0.1015 (0.1145)  loss_classifier: 0.0298 (0.0320)  loss_box_reg: 0.0658 (0.0666)  loss_objectness: 0.0023 (0.0040)  loss_rpn_box_reg: 0.0040 (0.0119)  time: 1.2071  data: 0.0296  max mem: 6404
# Epoch: [13]  [360/365]  eta: 0:00:06  lr: 0.000000  loss: 0.1140 (0.1145)  loss_classifier: 0.0305 (0.0320)  loss_box_reg: 0.0725 (0.0667)  loss_objectness: 0.0026 (0.0040)  loss_rpn_box_reg: 0.0077 (0.0119)  time: 1.2119  data: 0.0294  max mem: 6404
# Epoch: [13] Total time: 0:07:58
# creating index...
# index created!
# Test:  [  0/197]  eta: 0:03:37  model_time: 0.7072 (0.7072)  evaluator_time: 0.0074 (0.0074)  time: 1.1060  data: 0.3650  max mem: 6404
# Test:  [100/197]  eta: 0:00:42  model_time: 0.3825 (0.3828)  evaluator_time: 0.0065 (0.0080)  time: 0.4281  data: 0.0292  max mem: 6404
# Test: Total time: 0:01:25
# Averaged stats: model_time: 0.3813 (0.3805)  evaluator_time: 0.0079 (0.0131)
# Accumulating evaluation results...
# DONE (t=0.25s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.613
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.858
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.487
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.701
# Epoch: [14]  [  0/365]  eta: 0:26:29  lr: 0.000000  loss: 0.1943 (0.1943)  loss_classifier: 0.0546 (0.0546)  loss_box_reg: 0.1019 (0.1019)  loss_objectness: 0.0092 (0.0092)  loss_rpn_box_reg: 0.0286 (0.0286)  time: 4.3538  data: 0.4191  max mem: 6404
# Epoch: [14]  [ 10/365]  eta: 0:15:19  lr: 0.000000  loss: 0.0931 (0.1091)  loss_classifier: 0.0268 (0.0315)  loss_box_reg: 0.0568 (0.0640)  loss_objectness: 0.0023 (0.0035)  loss_rpn_box_reg: 0.0052 (0.0100)  time: 2.5896  data: 0.0647  max mem: 6404
# Epoch: [14]  [ 20/365]  eta: 0:10:16  lr: 0.000000  loss: 0.0805 (0.1002)  loss_classifier: 0.0240 (0.0288)  loss_box_reg: 0.0444 (0.0586)  loss_objectness: 0.0023 (0.0032)  loss_rpn_box_reg: 0.0048 (0.0097)  time: 1.6571  data: 0.0293  max mem: 6404
# Epoch: [14]  [ 30/365]  eta: 0:08:55  lr: 0.000000  loss: 0.1011 (0.1049)  loss_classifier: 0.0294 (0.0309)  loss_box_reg: 0.0568 (0.0621)  loss_objectness: 0.0032 (0.0032)  loss_rpn_box_reg: 0.0048 (0.0087)  time: 1.0554  data: 0.0294  max mem: 6404
# Epoch: [14]  [ 40/365]  eta: 0:09:20  lr: 0.000000  loss: 0.1025 (0.1064)  loss_classifier: 0.0294 (0.0309)  loss_box_reg: 0.0616 (0.0628)  loss_objectness: 0.0032 (0.0033)  loss_rpn_box_reg: 0.0045 (0.0094)  time: 1.6598  data: 0.0292  max mem: 6404
# Epoch: [14]  [ 50/365]  eta: 0:09:46  lr: 0.000000  loss: 0.1140 (0.1126)  loss_classifier: 0.0319 (0.0320)  loss_box_reg: 0.0717 (0.0666)  loss_objectness: 0.0031 (0.0036)  loss_rpn_box_reg: 0.0099 (0.0104)  time: 2.2659  data: 0.0290  max mem: 6404
# Epoch: [14]  [ 60/365]  eta: 0:09:54  lr: 0.000000  loss: 0.1188 (0.1163)  loss_classifier: 0.0339 (0.0328)  loss_box_reg: 0.0725 (0.0687)  loss_objectness: 0.0041 (0.0040)  loss_rpn_box_reg: 0.0106 (0.0108)  time: 2.4093  data: 0.0293  max mem: 6404
# Epoch: [14]  [ 70/365]  eta: 0:09:28  lr: 0.000000  loss: 0.1019 (0.1167)  loss_classifier: 0.0300 (0.0330)  loss_box_reg: 0.0624 (0.0686)  loss_objectness: 0.0039 (0.0041)  loss_rpn_box_reg: 0.0097 (0.0110)  time: 2.1005  data: 0.0292  max mem: 6404
# Epoch: [14]  [ 80/365]  eta: 0:08:54  lr: 0.000000  loss: 0.0999 (0.1161)  loss_classifier: 0.0297 (0.0329)  loss_box_reg: 0.0591 (0.0682)  loss_objectness: 0.0021 (0.0040)  loss_rpn_box_reg: 0.0109 (0.0110)  time: 1.6525  data: 0.0290  max mem: 6404
# Epoch: [14]  [ 90/365]  eta: 0:08:24  lr: 0.000000  loss: 0.1102 (0.1168)  loss_classifier: 0.0297 (0.0329)  loss_box_reg: 0.0638 (0.0689)  loss_objectness: 0.0020 (0.0040)  loss_rpn_box_reg: 0.0089 (0.0111)  time: 1.5050  data: 0.0290  max mem: 6404
# Epoch: [14]  [100/365]  eta: 0:07:49  lr: 0.000000  loss: 0.0988 (0.1146)  loss_classifier: 0.0262 (0.0321)  loss_box_reg: 0.0553 (0.0673)  loss_objectness: 0.0018 (0.0039)  loss_rpn_box_reg: 0.0089 (0.0113)  time: 1.3589  data: 0.0290  max mem: 6404
# Epoch: [14]  [110/365]  eta: 0:07:40  lr: 0.000000  loss: 0.0928 (0.1157)  loss_classifier: 0.0262 (0.0323)  loss_box_reg: 0.0553 (0.0679)  loss_objectness: 0.0028 (0.0039)  loss_rpn_box_reg: 0.0096 (0.0115)  time: 1.6625  data: 0.0291  max mem: 6404
# Epoch: [14]  [120/365]  eta: 0:07:28  lr: 0.000000  loss: 0.0931 (0.1135)  loss_classifier: 0.0276 (0.0318)  loss_box_reg: 0.0544 (0.0666)  loss_objectness: 0.0020 (0.0038)  loss_rpn_box_reg: 0.0074 (0.0112)  time: 2.1082  data: 0.0292  max mem: 6404
# Epoch: [14]  [130/365]  eta: 0:07:03  lr: 0.000000  loss: 0.0976 (0.1140)  loss_classifier: 0.0276 (0.0319)  loss_box_reg: 0.0544 (0.0664)  loss_objectness: 0.0020 (0.0038)  loss_rpn_box_reg: 0.0067 (0.0119)  time: 1.8039  data: 0.0293  max mem: 6404
# Epoch: [14]  [140/365]  eta: 0:06:50  lr: 0.000000  loss: 0.1222 (0.1170)  loss_classifier: 0.0361 (0.0328)  loss_box_reg: 0.0694 (0.0682)  loss_objectness: 0.0030 (0.0039)  loss_rpn_box_reg: 0.0107 (0.0120)  time: 1.8083  data: 0.0295  max mem: 6404
# Epoch: [14]  [150/365]  eta: 0:06:28  lr: 0.000000  loss: 0.1144 (0.1162)  loss_classifier: 0.0305 (0.0325)  loss_box_reg: 0.0741 (0.0680)  loss_objectness: 0.0025 (0.0039)  loss_rpn_box_reg: 0.0069 (0.0118)  time: 1.8112  data: 0.0294  max mem: 6404
# Epoch: [14]  [160/365]  eta: 0:06:13  lr: 0.000000  loss: 0.0984 (0.1154)  loss_classifier: 0.0269 (0.0324)  loss_box_reg: 0.0595 (0.0676)  loss_objectness: 0.0024 (0.0039)  loss_rpn_box_reg: 0.0059 (0.0115)  time: 1.8136  data: 0.0293  max mem: 6404
# Epoch: [14]  [170/365]  eta: 0:05:55  lr: 0.000000  loss: 0.1002 (0.1150)  loss_classifier: 0.0274 (0.0322)  loss_box_reg: 0.0620 (0.0674)  loss_objectness: 0.0024 (0.0039)  loss_rpn_box_reg: 0.
# Test:  [100/197]  eta: 0:00:42  model_time: 0.3816 (0.3840)  evaluator_time: 0.0063 (0.0081)  time: 0.4282  data: 0.0287  max mem: 6404
# Test: Total time: 0:01:25
# Averaged stats: model_time: 0.3794 (0.3807)  evaluator_time: 0.0079 (0.0131)
# Accumulating evaluation results...
# DONE (t=0.26s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.613
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.858
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.701

# %%
data_loader_test = torch.utils.data.DataLoader(
                        torch_dataset_test, batch_size=1, shuffle=False, num_workers=2,
                        collate_fn=utils.collate_fn)
evaluate(model, data_loader_test, device=torch.device('cuda'))
# Out:
# creating index...
# index created!
# Test:  [   0/1961]  eta: 0:13:24  model_time: 0.3172 (0.3172)  evaluator_time: 0.0027 (0.0027)  time: 0.4104  data: 0.0873  max mem: 6404
# Test:  [ 100/1961]  eta: 0:01:45  model_time: 0.0457 (0.0490)  evaluator_time: 0.0015 (0.0015)  time: 0.0530  data: 0.0038  max mem: 6404
# Test:  [ 200/1961]  eta: 0:01:36  model_time: 0.0458 (0.0477)  evaluator_time: 0.0013 (0.0015)  time: 0.0525  data: 0.0038  max mem: 6404
# Test:  [ 300/1961]  eta: 0:01:29  model_time: 0.0457 (0.0472)  evaluator_time: 0.0015 (0.0015)  time: 0.0529  data: 0.0037  max mem: 6404
# Test:  [ 400/1961]  eta: 0:01:23  model_time: 0.0456 (0.0468)  evaluator_time: 0.0014 (0.0016)  time: 0.0529  data: 0.0038  max mem: 6404
# Test:  [ 500/1961]  eta: 0:01:18  model_time: 0.0456 (0.0467)  evaluator_time: 0.0013 (0.0016)  time: 0.0531  data: 0.0038  max mem: 6404
# Test:  [ 600/1961]  eta: 0:01:13  model_time: 0.0462 (0.0468)  evaluator_time: 0.0012 (0.0016)  time: 0.0586  data: 0.0046  max mem: 6404
# Test:  [ 700/1961]  eta: 0:01:07  model_time: 0.0461 (0.0467)  evaluator_time: 0.0012 (0.0016)  time: 0.0548  data: 0.0038  max mem: 6404
# Test:  [ 800/1961]  eta: 0:01:02  model_time: 0.0460 (0.0467)  evaluator_time: 0.0013 (0.0016)  time: 0.0532  data: 0.0038  max mem: 6404
# Test:  [ 900/1961]  eta: 0:00:56  model_time: 0.0457 (0.0466)  evaluator_time: 0.0012 (0.0015)  time: 0.0524  data: 0.0038  max mem: 6404
# Test:  [1000/1961]  eta: 0:00:51  model_time: 0.0448 (0.0465)  evaluator_time: 0.0012 (0.0015)  time: 0.0509  data: 0.0038  max mem: 6404
# Test:  [1100/1961]  eta: 0:00:45  model_time: 0.0452 (0.0465)  evaluator_time: 0.0013 (0.0015)  time: 0.0520  data: 0.0038  max mem: 6404
# Test:  [1200/1961]  eta: 0:00:40  model_time: 0.0444 (0.0464)  evaluator_time: 0.0013 (0.0015)  time: 0.0516  data: 0.0038  max mem: 6404
# Test:  [1300/1961]  eta: 0:00:35  model_time: 0.0459 (0.0464)  evaluator_time: 0.0012 (0.0015)  time: 0.0522  data: 0.0037  max mem: 6404
# Test:  [1400/1961]  eta: 0:00:29  model_time: 0.0454 (0.0465)  evaluator_time: 0.0011 (0.0015)  time: 0.0527  data: 0.0037  max mem: 6404
# Test:  [1500/1961]  eta: 0:00:24  model_time: 0.0447 (0.0464)  evaluator_time: 0.0017 (0.0015)  time: 0.0525  data: 0.0039  max mem: 6404
# Test:  [1600/1961]  eta: 0:00:19  model_time: 0.0461 (0.0464)  evaluator_time: 0.0012 (0.0016)  time: 0.0578  data: 0.0038  max mem: 6404
# Test:  [1700/1961]  eta: 0:00:13  model_time: 0.0459 (0.0463)  evaluator_time: 0.0014 (0.0018)  time: 0.0532  data: 0.0040  max mem: 6404
# Test:  [1800/1961]  eta: 0:00:08  model_time: 0.0455 (0.0463)  evaluator_time: 0.0014 (0.0020)  time: 0.0536  data: 0.0038  max mem: 6404
# Test:  [1900/1961]  eta: 0:00:03  model_time: 0.0459 (0.0463)  evaluator_time: 0.0013 (0.0020)  time: 0.0529  data: 0.0038  max mem: 6404
# Test: Total time: 0:01:44
# Averaged stats: model_time: 0.0460 (0.0463)  evaluator_time: 0.0012 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.27s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.613
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.858
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.487
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.701

# %%
def convert_torch_predictions(preds, det_id, s_id, w, h, classes, ignore_thin_bbox=False):
    # Convert the outputs of the torch model into a FiftyOne Detections object
    dets = []
    for bbox, label, score in zip(
        preds["boxes"].cpu().detach().numpy(), 
        preds["labels"].cpu().detach().numpy(), 
        preds["scores"].cpu().detach().numpy()
    ):
        # Parse prediction into FiftyOne Detection object
        x0,y0,x1,y1 = bbox
        if ignore_thin_bbox:
            if (x1-x0) < 1 or (y1-y0) < 1:
                continue
        coco_obj = fouc.COCOObject(det_id, s_id, int(label), [x0, y0, x1-x0, y1-y0])
        det = coco_obj.to_detection((w,h), classes)
        det["confidence"] = float(score)
        dets.append(det)
        det_id += 1
        
    detections = fo.Detections(detections=dets)
        
    return detections, det_id

# %%
def add_detections(model, torch_dataset, view, field_name="predictions", ignore_thin_bbox=False):
    # Run inference on a dataset and add results to FiftyOne
    torch.set_num_threads(1)
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    print("Using device %s" % device)

    model.eval()
    model.to(device)
    image_paths = torch_dataset.img_paths
    classes = torch_dataset.classes
    det_id = 0
    
    with fo.ProgressBar() as pb:
        for img, targets in pb(torch_dataset):
            # Get FiftyOne sample indexed by unique image filepath
            img_id = int(targets["image_id"][0])
            img_path = image_paths[img_id]
            sample = view[img_path]
            s_id = sample.id
            w = sample.metadata["width"]
            h = sample.metadata["height"]
            
            # Inference
            preds = model(img.unsqueeze(0).to(device))[0]
            
            detections, det_id = convert_torch_predictions(
                preds, 
                det_id, 
                s_id, 
                w, 
                h, 
                classes,
            )
            
            sample[field_name] = detections
            sample.save()

# %%
session.view = dataset_test.sort_by("eval_frcnn_fp", reverse=True)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=474b758a-6c6d-4225-9509-68b7f9ebcf41"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
file_name = f"{datetime.now().strftime('%m_%d_%y, %H-%M-%S')}e15.pt"
file_name
# Out:
# '04_21_23, 19-34-11e15.pt'

# %%
# https://pytorch.org/tutorials/beginner/saving_loading_models.html
# Saving Model
torch.save(model.state_dict(), os.path.abspath(f"faster_rcnn_resnet_weights/{file_name}"))

# %% [markdown]
# # LOADING MODEL

# %%
# loading the model from saved state
PATH = "faster_rcnn_resnet_weights/23_04_21--19-38-02e15.pt"
model = get_model(2)
model.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
add_detections(model, torch_dataset_test, dataset_test, field_name="predictions_frcnn")
# Out:
# Using device cuda
#  100% |███████████████| 1961/1961 [3.0m elapsed, 0s remaining, 13.6 samples/s]

# %%
dataset_test
# Out:
# Name:        HRSID_test
# Media type:  image
# Num samples: 1961
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:                  fiftyone.core.fields.ObjectIdField
#     filepath:            fiftyone.core.fields.StringField
#     tags:                fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:            fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     detections:          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     segmentations:       fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     predictions_lee:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     seg_predictions_lee: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     eval_seg2_tp:        fiftyone.core.fields.IntField
#     eval_seg2_fp:        fiftyone.core.fields.IntField
#     eval_seg2_fn:        fiftyone.core.fields.IntField
#     eval_tp:             fiftyone.core.fields.IntField
#     eval_fp:             fiftyone.core.fields.IntField
#     eval_fn:             fiftyone.core.fields.IntField
#     predictions_frcnn:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     eval_frcnn_tp:       fiftyone.core.fields.IntField
#     eval_frcnn_fp:       fiftyone.core.fields.IntField
#     eval_frcnn_fn:       fiftyone.core.fields.IntField

# %%
dataset_train
# Out:
# Name:        HRSID_train
# Media type:  image
# Num samples: 3642
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:                  fiftyone.core.fields.ObjectIdField
#     filepath:            fiftyone.core.fields.StringField
#     tags:                fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:            fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     detections:          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     segmentations:       fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     predictions_lee:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     seg_predictions_lee: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     eval_seg_tp:         fiftyone.core.fields.IntField
#     eval_seg_fp:         fiftyone.core.fields.IntField
#     eval_seg_fn:         fiftyone.core.fields.IntField
#     eval_tp:             fiftyone.core.fields.IntField
#     eval_fp:             fiftyone.core.fields.IntField
#     eval_fn:             fiftyone.core.fields.IntField
#     predictions_frcnn:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     eval_frcnn_tp:       fiftyone.core.fields.IntField
#     eval_frcnn_fp:       fiftyone.core.fields.IntField
#     eval_frcnn_fn:       fiftyone.core.fields.IntField

# %%
results = fo.evaluate_detections(
    dataset_test, 
    "predictions_frcnn", 
    classes=["ship"],
    eval_key="eval_frcnn", 
    compute_mAP=True,
    gt_field='detections'
)
# Out:
# Evaluating detections...
#  100% |███████████████| 1961/1961 [43.4s elapsed, 0s remaining, 73.2 samples/s]
# Performing IoU sweep...
#  100% |███████████████| 1961/1961 [25.0s elapsed, 0s remaining, 101.8 samples/s]

# %%
results.mAP()
# Out:
# 0.6131548779835022

# %%
results.print_report()
# Out:
#               precision    recall  f1-score   support
#
#         ship       0.20      0.91      0.33      5921
#
#    micro avg       0.20      0.91      0.33      5921
#    macro avg       0.20      0.91      0.33      5921
# weighted avg       0.20      0.91      0.33      5921

# %%
add_detections(model, torch_dataset, dataset_train, field_name="predictions_frcnn")
# Out:
# Using device cuda
#  100% |███████████████| 3642/3642 [5.7m elapsed, 0s remaining, 11.8 samples/s]

# %%
results = fo.evaluate_detections(
    dataset_train, 
    "predictions_frcnn", 
    classes=["ship"],
    eval_key="eval_frcnn", 
    compute_mAP=True,
    gt_field='detections'
)
# Out:
# Evaluating detections...
#  100% |███████████████| 3642/3642 [1.4m elapsed, 0s remaining, 71.7 samples/s]
# Performing IoU sweep...
#  100% |███████████████| 3642/3642 [45.3s elapsed, 0s remaining, 92.6 samples/s]

# %%
results.mAP()
# Out:
# 0.6670056311532374

# %%
results.print_report()
# Out:
#               precision    recall  f1-score   support
#
#         ship       0.21      0.93      0.34     11047
#
#    micro avg       0.21      0.93      0.34     11047
#    macro avg       0.21      0.93      0.34     11047
# weighted avg       0.21      0.93      0.34     11047

# %% [markdown]
# # small set

# %%
small_set = dataset_test[:8]
torch_small_set = HRSIDDetectionDataset(small_set, transforms=test_transforms)

# %%
add_detections(model, torch_small_set, small_set, field_name="predictions")
# Out:
# Using device cuda
#  100% |█████████████████████| 8/8 [2.4s elapsed, 0s remaining, 3.3 samples/s]

# %% [markdown]
# # Ignoring bboxes on edges
# evaluation with bboxes on edges ignored. Done by calculating if the bbox is just a line, since most falsely detected bboxes on the edges are lines

# %%
add_detections(model, torch_dataset_test, dataset_test, field_name="predictions_frcnn_bbox_ignore")
# Out:
# Using device cuda
#  100% |███████████████| 1961/1961 [3.3m elapsed, 0s remaining, 9.2 samples/s]

# %%
results = fo.evaluate_detections(
    dataset_test, 
    "predictions_frcnn_bbox_ignore", 
    classes=["ship"],
    eval_key="eval_frcnn_bbox_ignore", 
    compute_mAP=True,
    gt_field='detections'
)
# Out:
# Sample field 'eval_frcnn_bbox_ignore_tp' does not exist
# Sample field 'eval_frcnn_bbox_ignore_fp' does not exist
# Sample field 'eval_frcnn_bbox_ignore_fn' does not exist
# Evaluating detections...
#  100% |███████████████| 1961/1961 [44.2s elapsed, 0s remaining, 66.3 samples/s]
# Performing IoU sweep...
#  100% |███████████████| 1961/1961 [25.8s elapsed, 0s remaining, 98.0 samples/s]

# %%
print(results.mAP())
results.print_report()
# Out:
# 0.6131548779835022
#               precision    recall  f1-score   support
#
#         ship       0.20      0.91      0.33      5921
#
#    micro avg       0.20      0.91      0.33      5921
#    macro avg       0.20      0.91      0.33      5921
# weighted avg       0.20      0.91      0.33      5921

# %%
add_detections(model, torch_dataset, dataset_train, field_name="predictions_frcnn_bbox_ignore")
# Out:
# Using device cuda
#  100% |███████████████| 3642/3642 [6.1m elapsed, 0s remaining, 9.8 samples/s]

# %%
results = fo.evaluate_detections(
    dataset_train, 
    "predictions_frcnn_bbox_ignore", 
    classes=["ship"],
    eval_key="eval_frcnn_bbox_ignore", 
    compute_mAP=True,
    gt_field='detections'
)
# Out:
# Evaluating detections...
#  100% |███████████████| 3642/3642 [1.4m elapsed, 0s remaining, 70.1 samples/s]
# Performing IoU sweep...
#  100% |███████████████| 3642/3642 [45.6s elapsed, 0s remaining, 91.0 samples/s]

# %%
print(results.mAP())
results.print_report()
# Out:
# 0.6670056311532374
#               precision    recall  f1-score   support
#
#         ship       0.21      0.93      0.34     11047
#
#    micro avg       0.21      0.93      0.34     11047
#    macro avg       0.21      0.93      0.34     11047
# weighted avg       0.21      0.93      0.34     11047
